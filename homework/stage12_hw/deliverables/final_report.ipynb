# %% [markdown]
# ## Executive summary
# This dataset demonstrate different values of metrics by leveraging three different cleanin strategy, baseline, filling median, and removing outliers. The strategy altering outliers demonstrated the highest return with the highest volatility. The baseline model showed the lowest volatility with higher return than model of filling median. We found that stakeholder could choose using baseline model or model with stratgey of removing outliers according to different risk budget.

# %% [markdown]
# ## Chart with interpretations
# ![截屏2025-08-28 13.19.37.png](<attachment:截屏2025-08-28 13.19.37.png>)

# %% [markdown]
# The risk return scatter plot demonstrates three different scenarios, baseline, filling median and removing outliers. Removing outliers provided higher return with highest volatility, and the baseline model provided lowest volatility with higher return than filling median. Filling median offered lowest return with higher volatility than baseline model. Therefore, filling median is not a great strategy to model this dataset. And stakeholder could choose either baseline or removing outliers based on how much risk they can tolerate. However, we might assume the outliers are not true important financial events, otherwise we might underestimate the volatility.

# %% [markdown]
# ![截屏2025-08-28 13.28.23.png](<attachment:截屏2025-08-28 13.28.23.png>)

# %% [markdown]
# This barplot showes the return based on different scenario without risk demonstrating. The strategy of removing outliers reflects the highest return, and filling median reflects the lowest return. However, the potential risks is the plot might mislead stakeholder to make decisions because of no risk measurement. In order to use this plot, we might assume the volatility are constant which are impossible in the real world situation.

# %% [markdown]
# ![截屏2025-08-28 13.32.23.png](<attachment:截屏2025-08-28 13.32.23.png>)

# %% [markdown]
# This plot showes how metric A changed over time on category Y and category Z. We can see there is a positive signal of mertic A growing on category Y. We are not able to see the trendy of mertic A on category Y since we only have one observation. Stakeholder are difficult to make decisons on this plot since the sample size is too small.

# %% [markdown]
# ## Sensitivity summary

# %% [markdown]
# ![截屏2025-08-28 13.41.38.png](<attachment:截屏2025-08-28 13.41.38.png>)

# %% [markdown]
# After applying filling median and removing outliers, the baseline return drop from 12% to 10% or 14%, which means there are no significantly changed. We can conclude that the return are robustness, and will not be impact significantly by filling median and removing outliers.

# %% [markdown]
# ## Decision making
# I suggest stakeholders using baseline or removing outliers based on range of risks they can tolerate. For stakeholders who can tolerate higher range of risks, I suggest they remove outliers to achieve higher return. For stakeholder who pursue more stable return and lower volatility, I sugget they use baseline model.
